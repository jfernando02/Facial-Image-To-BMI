# %%
# !git clone https://github.com/jfernando02/Facial-Image-To-BMI.git
# Out:
# Cloning into 'Facial-Image-To-BMI'...
# remote: Enumerating objects: 4300, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 4300 (delta 41), reused 47 (delta 18), pack-reused 4228 (from 1)
# Receiving objects: 100% (4300/4300), 941.72 MiB | 16.53 MiB/s, done.
# Resolving deltas: 100% (180/180), done.
# Updating files: 100% (3979/3979), done.

# %%
# %cd Facial-Image-To-BMI/scripts
# Out:
# /content/Facial-Image-To-BMI/scripts

# %%
# !python run.py --augmented True --detection none
# !python run.py --augmented False --detection none
# !python run.py --augmented True --detection edge
# !python run.py --augmented False --detection edge
# !python run.py --augmented True --detection segmentation
# !python run.py --augmented False --detection segmentation
# Out:
# Epoch 1
# -------------------------------
# train loss: 1072.202637 [    0/ 3415]
# train loss: 207.867279 [  960/ 3415]
# train loss: 85.091904 [ 1920/ 3415]
# train loss: 43.192200 [ 2880/ 3415]
# val mse loss: 26.432910, val mae loss: 3.5250668869791593
# Validation loss decreased (inf --> 3.525067).  Saving model ...
# Epoch 2
# -------------------------------
# train loss: 46.518288 [    0/ 3415]
# train loss: 67.475479 [  960/ 3415]
# train loss: 26.062778 [ 1920/ 3415]
# train loss: 52.442078 [ 2880/ 3415]
# val mse loss: 31.544357, val mae loss: 4.8661635727164025
# EarlyStopping counter: 1 out of 3
# ...

# %%
# !python run.py --augmented True --detection none
# !python run.py --augmented False --detection none
# !python run.py --augmented True --detection edge
# !python run.py --augmented False --detection edge
# !python run.py --augmented True --detection segmentation
# !python run.py --augmented False --detection segmentation

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp /content/Facial-Image-To-BMI/weights /content/drive/MyDrive/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
